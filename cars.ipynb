# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('cars.csv')

# %%
df.head(30)
# Out:
#      mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0   14.0           8          350  165       4209           12   1972
# 1   31.9           4           89   71       1925           14   1980
# 2   17.0           8          302  140       3449           11   1971
# 3   15.0           8          400  150       3761           10   1971
# 4   30.5           4           98   63       2051           17   1978
# 5   23.0           8          350  125       3900           17   1980
# 6   13.0           8          351  158       4363           13   1974
# 7   14.0           8          440  215       4312            9   1971
# 8   25.4           5          183   77       3530           20   1980
# 9   37.7           4           89   62       2050           17   1982
# 10  34.0           4          108   70       2245           17   1983
# 11  34.3           4           97   78       2188           16   1981
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           261 non-null    float64
#  1    cylinders    261 non-null    int64
#  2    cubicinches  261 non-null    object
#  3    hp           261 non-null    int64
#  4    weightlbs    261 non-null    object
#  5    time-to-60   261 non-null    int64
#  6    year         261 non-null    int64
#  7    brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# what is the relation between mpg and cubicinches ?
# what is the relation between mpg and weight ?
# what is the relation between mp and year of manf ?

# %%
df.describe()
# Out:
#               mpg   cylinders          hp   time-to-60         year
# count  261.000000  261.000000  261.000000   261.000000   261.000000
# mean    23.144828    5.590038  106.360153    15.547893  1976.819923
# std      7.823570    1.733310   40.499959     2.910625     3.637696
# min     10.000000    3.000000   46.000000     8.000000  1971.000000
# 25%     16.900000    4.000000   75.000000    14.000000  1974.000000
# 50%     22.000000    6.000000   95.000000    16.000000  1977.000000
# 75%     28.800000    8.000000  138.000000    17.000000  1980.000000
# max     46.600000    8.000000  230.000000    25.000000  1983.000000

# %%
df.columns
# Out:
# Index(['mpg', ' cylinders', ' cubicinches', ' hp', ' weightlbs', ' time-to-60',
#        ' year', ' brand'],
#       dtype='object')

# %%
df[' year'].value_counts()
# Out:
# 1974    35
# 1977    26
# 1971    23
# 1976    22
# 1980    21
# 1979    21
# 1978    18
# 1982    18
# 1981    18
# 1983    16
# 1973    16
# 1972    15
# 1975    12
# Name:  year, dtype: int64

# %%
np.sort(df[' year'].unique())
# Out:
# array([1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983], dtype=int64)

# %%
df[' year'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
bin_edges = [1970, 1975, 1979, 1983] # Fill in this list

# %%
bin_names = ['old', 'medium', 'recent']

# %%
df['man_year'] = pd.cut(df[' year'], bin_edges, labels=bin_names)

# %%
year_median = df[' year'].mean()

# %%
#plt.axvline(year_median , color ='r', linewidth =2 , label = 'year median')
df['man_year'].hist()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#     mpg   cylinders  cubicinches   hp  weightlbs   time-to-60   year  \
# 0  14.0           8          350  165       4209           12   1972
# 1  31.9           4           89   71       1925           14   1980
# 2  17.0           8          302  140       3449           11   1971
# 3  15.0           8          400  150       3761           10   1971
# 4  30.5           4           98   63       2051           17   1978
#
#       brand man_year
# 0       US.      old
# 1   Europe.   recent
# 2       US.      old
# 3       US.      old
# 4       US.   medium
